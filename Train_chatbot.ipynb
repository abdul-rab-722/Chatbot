# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

#import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# ## Preprocess data

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ## Create training and testing data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-18-451aefdaa425>:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %% [markdown]
# ## Build the model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 7ms/step - loss: 2.2049 - accuracy: 0.1064
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1965 - accuracy: 0.1702
# Epoch 3/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0733 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0017 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8410 - accuracy: 0.4043
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7527 - accuracy: 0.5319
# Epoch 7/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.5922 - accuracy: 0.4894
# Epoch 8/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5585 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3503 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1950 - accuracy: 0.6809
# Epoch 11/200
# 10/10 [==============================] - ETA: 0s - loss: 1.2549 - accuracy: 0.60 - 0s 5ms/step - loss: 1.1855 - accuracy: 0.6596
# Epoch 12/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0235 - accuracy: 0.7447
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9998 - accuracy: 0.6596
# Epoch 14/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7719 - accuracy: 0.8298
# Epoch 15/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8029 - accuracy: 0.7234
# Epoch 16/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7226 - accuracy: 0.7447
# Epoch 17/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6600 - accuracy: 0.7660
# Epoch 18/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5932 - accuracy: 0.7872
# Epoch 19/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6369 - accuracy: 0.8723
# Epoch 20/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4850 - accuracy: 0.9149
# Epoch 21/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4170 - accuracy: 0.8936
# Epoch 22/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5615 - accuracy: 0.8511
# Epoch 23/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3632 - accuracy: 0.9149
# Epoch 24/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5531 - accuracy: 0.7872
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3800 - accuracy: 0.8511
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3666 - accuracy: 0.9149
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2212 - accuracy: 0.9787
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2423 - accuracy: 0.9574
# Epoch 29/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3771 - accuracy: 0.9149
# Epoch 30/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3251 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3549 - accuracy: 0.8936
# Epoch 32/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1682 - accuracy: 0.9574
# Epoch 33/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2615 - accuracy: 0.9149
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2096 - accuracy: 0.9787
# Epoch 35/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1097 - accuracy: 1.0000
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 1.0000
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1784 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.9362
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2374 - accuracy: 0.9362
# Epoch 40/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1390 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9787
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2382 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0648 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1206 - accuracy: 0.9362
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9149
# Epoch 60/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0815 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0890 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1102 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0380 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0628 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0815 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1262 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9574
# Epoch 77/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9574
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1024 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1206 - accuracy: 0.9574
# Epoch 82/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1411 - accuracy: 0.9362
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.97 - 0s 7ms/step - loss: 0.0483 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1265 - accuracy: 0.9362
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0871 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0614 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0744 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0754 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0947 - accuracy: 0.9574
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0495 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0580 - accuracy: 0.9787
# Epoch 114/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0461 - accuracy: 0.9787 0s - loss: 0.0610 - accuracy: 0.97
# Epoch 116/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0512 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0682 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0495 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0729 - accuracy: 0.9574
# Epoch 123/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0277 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1282 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0850 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9787
# Epoch 140/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0685 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0918 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0379 - accuracy: 0.9787
# Epoch 154/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0035 - accuracy: 1.0000ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0558 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0093 - accuracy: 1.0000 0s - loss: 0.0109 - accuracy: 1.00
# Epoch 163/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9787
# Epoch 171/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0429 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.00 - 0s 18ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0349 - accuracy: 0.9787 0s - loss: 0.0064 - accuracy: 1.
# Epoch 191/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# model created
